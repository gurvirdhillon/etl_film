# %% [markdown]
# # Exploratory Data Analysis of Country table

# %%
import pandas as pd

# %%
country = pd.read_csv("../data/output/country.csv")

country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country_id   109 non-null    int64
#  1   country      109 non-null    object
#  2   last_update  109 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.7+ KB

# %% [markdown]
# ### Missing data
#
# It is apparent there are no nulls in the country table

# %% [markdown]
# ### Duplicates

# %%
country.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# It is apparent there are no duplicated records in the country table
