# %% [markdown]
# # Exploratory Data Analysis of City table

# %%
import pandas as pd

# %%
city = pd.read_csv("../data/output/city.csv")

city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city_id      600 non-null    int64
#  1   city         600 non-null    object
#  2   country_id   600 non-null    int64
#  3   last_update  600 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Missing data
#
# It is apparent there are no nulls in the city table

# %% [markdown]
# ### Duplicates

# %%
city.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# It is apparent there are no duplicated records in the city table
