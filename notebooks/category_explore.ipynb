# %% [markdown]
# # Exploratory Data Analysis of Category table

# %%
import pandas as pd

# %%
category = pd.read_csv("../data/output/category.csv")

category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 516.0+ bytes

# %% [markdown]
# ### Missing data
#
# It is apparent there are no nulls in the category table

# %% [markdown]
# ### Duplicates

# %%
category.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# It is apparent there are no duplicated records in the category table
