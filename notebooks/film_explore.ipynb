# %% [markdown]
# # Exploratory Data Analysis of film table

# %%
import pandas as pd

# %%
film = pd.read_csv("../data/output/film.csv")

film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   int64
#  1   title             1000 non-null   object
#  2   description       1000 non-null   object
#  3   release_year      1000 non-null   int64
#  4   language_id       1000 non-null   int64
#  5   rental_duration   1000 non-null   int64
#  6   rental_rate       1000 non-null   float64
#  7   length            1000 non-null   int64
#  8   replacement_cost  1000 non-null   float64
#  9   rating            1000 non-null   object
#  10  last_update       1000 non-null   object
#  11  special_features  1000 non-null   object
#  12  fulltext          1000 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 101.7+ KB

# %% [markdown]
# ### Missing data
#
# It is apparent there are no nulls in the film table

# %% [markdown]
# ### Duplicates

# %%
film.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# It is apparent there are no duplicated records in the film table
